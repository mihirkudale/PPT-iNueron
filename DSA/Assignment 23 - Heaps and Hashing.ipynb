# %% [markdown]
# # Assignment 23 - Heaps and Hashing

# %% [markdown]
# Question-1:
#
# Given preorder of a binary tree, calculate its [depth(or height)] [starting from depth 0]. The preorder is given as a string with two possible characters.
#
# 1. ‘l’ denotes the leaf
# 2. ‘n’ denotes internal node
#
# The given tree can be seen as a full binary tree where every node has 0 or two children. The two children of a node can ‘n’ or ‘l’ or mix of both.
#
# **Examples :**
#
# Input  : nlnll
#
# Output : 2
#
# Explanation :
#
# ![btree1.png](attachment:btree1.png)

# %% [markdown]
# Input  : nlnnlll
#
# Output : 3

# %% [markdown]
# ![dia2.png](attachment:dia2.png)

# %%
def find_depth(preorder):
  depth = 0
  for i in range(len(preorder)):
    if preorder[i] == "n":
      depth += 1
  return depth


def main():
  preorder = "nlnll"
  print(find_depth(preorder))


if __name__ == "__main__":
  main()
# Out:
# 2

# %% [markdown]
# Question-2:
#
# Given a Binary tree, the task is to print the **left view** of the Binary Tree. The left view of a Binary Tree is a set of leftmost nodes for every level.
#
# **Examples:**
#
# ***Input:***
#
#             4
#
#           /   \
#
#         5     2
#
#              /   \
#
#             3     1
#
#            /  \
#
#           6    7
#
# ***Output:** 4 5 3 6*
#
# **Explanation:**

# %% [markdown]
# ![left-view.png](attachment:left-view.png)

# %% [markdown]
# ***Input:***
#
#                     1
#
#                   /   \
#
#                 2       3
#
#                  \
#
#                    4
#
#                      \
#
#                         5
#
#                            \
#
#                              6
#
# **Output:** 1 2 4 5 6

# %%
class BinaryTree:
  def __init__(self, value):
    self.value = value
    self.left = None
    self.right = None

def left_view(tree):
  """Finds the left view of a binary tree."""
  if tree is None:
    return []

  left_view_list = []
  queue = [tree]

  while queue:
    node = queue.pop(0)
    left_view_list.append(node.value)

    if node.left:
      queue.append(node.left)

    if node.right:
      queue.append(node.right)

  return left_view_list

if __name__ == "__main__":
  tree = BinaryTree(1)
  tree.left = BinaryTree(2)
  tree.left.left = BinaryTree(4)
  tree.left.right = BinaryTree(5)
  tree.right = BinaryTree(3)
  tree.right.right = BinaryTree(6)

  left_view_list = left_view(tree)

  print(left_view_list)
# Out:
# [1, 2, 3, 4, 5, 6]
